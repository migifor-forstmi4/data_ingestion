# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
from pandas import json_normalize
import requests
import json
import folium

# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)
df.head(5)
# Out:
#    type        id        lat       lon tags.addr:city tags.addr:country  \
# 0  node  33126515  47.155616  9.037915        Schänis                CH
# 1  node  36726161  47.226191  8.980329         Uznach               NaN
# 2  node  39768209  47.225154  8.969868         Uznach               NaN
# 3  node  39947904  47.376732  8.542161         Zürich                CH
# 4  node  48932835  47.375020  8.522895         Zürich               NaN
#
#   tags.addr:housenumber tags.addr:postcode tags.addr:street tags.brand  ...  \
# 0                    32               8718   Biltnerstrasse       Spar  ...
# 1                    25               8730   Zürcherstrasse     Migros  ...
# 2                   NaN               8730              NaN       Coop  ...
# 3                     1               8001    Bahnhofbrücke       Coop  ...
# 4                     7               8004     Wengistrasse     Migros  ...
#
#   tags.postid tags.diet:local tags.payment:account_cards  \
# 0         NaN             NaN                        NaN
# 1         NaN             NaN                        NaN
# 2         NaN             NaN                        NaN
# 3         NaN             NaN                        NaN
# 4         NaN             NaN                        NaN
#
#   tags.diet:mediterranean tags.diet:organic tags.diet:seafood  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#   tags.recycling:low_energy_bulbs tags.opening_hours:cafe tags.name:zh-Hans  \
# 0                             NaN                     NaN               NaN
# 1                             NaN                     NaN               NaN
# 2                             NaN                     NaN               NaN
# 3                             NaN                     NaN               NaN
# 4                             NaN                     NaN               NaN
#
#   tags.panoramax
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 278 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Coop', 'Migros'])]
print(locations.head(5))

# Subsets
locations_coop = df[["lat", "lon", "tags.brand",
                     "tags.shop"]].loc[df["tags.brand"].isin(['Coop'])]
locations_migros = df[["lat", "lon", "tags.brand",
                       "tags.shop"]].loc[df["tags.brand"].isin(['Migros'])]

# Marker symbols
url_01 = 'https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png'
url_02 = 'https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-orange.png'

# Create map
map = folium.Map(location=[locations.lat.mean(),
                           locations.lon.mean()],
                 zoom_start=8,
                 control_scale=True)

# Add lat/lon of Coop supermarkets
for i in range(0, len(locations_coop)):
    folium.Marker(location=(locations_coop.iloc[i]['lat'],
                            locations_coop.iloc[i]['lon']),
                  popup=locations_coop.iloc[i]['tags.brand'],
                  icon=folium.features.CustomIcon(url_01, icon_size=(16, 28))).add_to(map)
    
# Add lat/lon of Migros supermarkets
for i in range(0, len(locations_migros)):
    folium.Marker(location=(locations_migros.iloc[i]['lat'],
                            locations_migros.iloc[i]['lon']),
                  popup=locations_migros.iloc[i]['tags.brand'],
                  icon=folium.features.CustomIcon(url_02, icon_size=(16, 28))).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 6  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a29206b3f67a8988b3a1d92dcd57b19f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a29206b3f67a8988b3a1d92dcd57b19f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a29206b3f67a8988b3a1d92dcd57b19f = L.map(
#                 &quot;map_a29206b3f67a8988b3a1d92dcd57b19f&quot;,
#                 {
#                     center: [47.010083662850086, 8.004460116721582],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a29206b3f67a8988b3a1d92dcd57b19f);
#
#
#
#
#
#             var tile_layer_548f9a28d792e28525840b203e997154 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_548f9a28d792e28525840b203e997154.addTo(map_a29206b3f67a8988b3a1d92dcd57b19f);
#
#
#             var marker_cf43168213d5ab401147d12008367bd0 = L.marker(
#                 [47.2251539, 8.9698681],
#                 {
# }
#             ).addTo(map_a29206b3f67a8988b3a1d92dcd57b19f);
#
#
#         var icon_db3f1a414ae9b1aa43f209b68dd84e3a = L.icon({
#   &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;,
#   &quot;iconSize&quot;: [16, 28],
# });
#
#
#         var popup_cd3676a3e7550dda653c4354e50a8a95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_042ae7fd9dd71627ce890876ff72fc56 = $(`&lt;div id=&quot;html_042ae7fd9dd71627ce890876ff72fc56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_cd3676a3e7550dda653c4354e50a8a95.setContent(html_042ae7fd9dd71627ce890876ff72fc56);
#
#
#
#         marker_cf43168213d5ab401147d12008367bd0.bindPopup(popup_cd3676a3e7550dda653c4354e50a8a95)
#         ;
#
#
#
#
#                 marker_cf43168213d5ab401147d12008367bd0.setIcon(icon_db3f1a414ae9b1aa43f209b68dd84e3a);
#
#
#             var marker_c1bf2b21a3574881a35db9537210fbc5 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {
# }
#             ).addTo(map_a29206b3f67a8988b3a1d92dcd57b19f);
#
#
#         var icon_262e3929affa0d60c6ea0fe4f96797ea = L.icon({
#   &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;,
#   &quot;iconSize&quot;: [16, 28],
# });
#
#
#         var popup_4cf0a4ade94530573172b8d954007d7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da178ff0eb839f9c9c2546b8f647902f = $(`&lt;div id=&quot;html_da178ff0eb839f9c9c2546b8f647902f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_4cf0a4ade94530573172b8d954007d7a.setContent(html_da178ff0eb839f9c9c2546b8f647902f);
#
#
#
#         marker_c1bf2b21a3574881a35db9537210fbc5.bindPopup(popup_4cf0a4ade94530573172b8d954007d7a)
#         ;
#
#
#
#
#                 marker_c1bf2b21a3574881a35db9537210fbc5.setIcon(icon_262e3929affa0d60c6ea0fe4f96797ea);
#
#
#             var marker_bcfe7d1adde94275a56b6ebd081b788a = L.marker(
#                 [47.3400698, 8.5305461],
#                 {
# }
#             ).addTo(map_a29206b3f67a8988b3a1d92dcd57b19f);
#
#
#         var icon_42079abac50ba99858936a18c0d4e63d = L.icon({
#   &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;,
#   &quot;iconSize&quot;: [16, 28],
# });
#
#
#         var popup_8727c587c32647649afe59e5033f7737 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d719d4f3909d0d3903f973ccddac0324 = $(`&lt;div id=&quot;html_d719d4f3909d0d3903f973ccddac0324&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_8727c587c32647649afe59e5033f7737.setContent(html_d719d4f3909d0d3903f973ccddac0324);
#
#
#
#         marker_bcfe7d1adde94275a56b6ebd081b788a.bindPopup(popup_8727c587c32647649afe59e5033f7737)
#         ;
#
#
#
#
#                 marker_bcfe7d1adde94275a56b6ebd081b788a.setIcon(icon_42079abac50ba99858936a18c0d4e63d);
#
#
#             var marker_5eff6b310cba6b3fca5fe95be9e9e7dc = L.marker(
#                 [47.241531, 8.7245301],
#                 {
# }
#             ).addTo(map_a29206b3f67a8988b3a1d92dcd57b19f);
#
#
#         var icon_058cc585b6f4a78bb62ce94a02b7f13c = L.icon({
#   &quot;iconUrl&quot;: &quot;https://raw.githubuser

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-11-09 18:57:40
# Python Version: 3.11.14
# -----------------------------------
