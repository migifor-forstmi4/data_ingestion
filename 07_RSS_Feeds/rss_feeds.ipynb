# %% [markdown]
# # Getting Text data from RSS-Feeds

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import feedparser
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Settings
import warnings
warnings.filterwarnings("ignore")

# Current working directory
print(f'Current working directory: {os.getcwd()}')
# Out:
# Current working directory: /workspaces/data_ingestion/07_RSS_Feeds

# %% [markdown]
# ## Parse the RSS feed

# %%
# RSS feeds from NZZ website
feed = feedparser.parse("https://www.nzz.ch/startseite.rss")

# %% [markdown]
# ## Extract the data

# %%
# Get data from RSS feeds
feed_entries = feed.entries

# Initialize an empty string to store the text
wordcloud_text = ""

# Show first RSS-feeds
print("Article Titles:")
for entry in feed.entries:

    article_title = entry.title
    article_link = entry.link
    article_published_at = entry.published
    article_published_at_parsed = entry.published_parsed

    # Append the title to the wordcloud_text
    wordcloud_text += f"{article_title} "

    # Change and format output
    print(f"{article_title}")
    # print(f"{article_title}[{article_link}]")
    # print(f"Published at {article_published_at}")
# Out:
# Article Titles:
# «Cowboy-Weltpolitik»: Die Schweizer Politik reagiert empört auf den Unternehmerbesuch bei Donald Trump
# Die ungleichen Brüder Shakarchi: Der Ältere stürzte die Schweiz in ihre grösste politische Krise, der Jüngere hilft dem Land im Zollstreit
# Ein aggressives Atemholen mit Kalkül – was ein Waffenstillstand im Nahen Osten bedeutet
# INTERVIEW - «Wenn die Zuwanderer illegal hierherkommen, haben sie kein Recht zu bleiben», sagt der ehemalige Tory-Politiker Lord Frost. Das müsse allen klar werden
# «Die erste Liebe gibt uns eine neue Identität», sagt die Psychologin
# Der Scheich, der Afrikas schlimmsten Krieg steuert: Auf Mansur bin Zayed Al Nahyan kann sich die Mördertruppe RSF im Sudan verlassen
# Nach der Wahlniederlage vom Dienstag getrauen sich Republikaner, dem US-Präsidenten offen zu widersprechen. Hat jetzt Trumps Lahme-Ente-Phase begonnen?
# Mit der Krankheit leben und lieben, solange es geht
# INTERVIEW - «Ich dachte ein paarmal, ich wäre lieber ein Jahr im Koma gewesen als in der Psychose» – Der frühere Fussballer Kay Voser kämpft um ein neues Leben
# SERIE - Gesund altern: wie sich normale Veränderungen im Gehirn von einer Demenz oder Parkinson unterscheiden lassen
# Die Insel Bali war ein Paradies. Dann kamen die digitalen Nomaden
# Auf dem Marktplatz in Oerlikon treffen sich Männer aus dem Balkan zum Schach. Sie spielen gegen Einsamkeit und Heimweh
# DOK-FILM «NZZ FORMAT» - Diagnose unbekannt – unser Dok-Film über zwei Patientinnen, die seit Jahren um medizinische Klarheit kämpfen
# «De Irrsinn gaad mir nöd in Chopf ine»: Roger Schawinski kämpft gegen die SRG und für seine grosse Liebe
# PODCAST «NZZ GEOPOLITIK» - Nepal, Peru, Madagaskar, und es werden immer mehr: Welchen Effekt haben die weltweiten Proteste der Generation Z?
# Drei Tote und fünfzehn Verletzte durch Riesenwellen auf Teneriffa
# Planen US-Geheimdienste die Infiltration der grönländischen Gesellschaft? Ein Besuch in Nuuk
# Berlin, du kannst so hässlich sein: Die Hauptstädter verzweifeln langsam an ihrer Stadt
# «Die Menschen flogen wie Schnee, der von einem Pflug zur Seite geschoben wird» – Besuch auf dem Weihnachtsmarkt in Magdeburg, ein Jahr nach dem Horror
# Bei Elon Musk geht es um mehr als Geld – trotz Bonus von einer Billion Dollar
# «Der Skimarkt wird nicht mehr wachsen. Wir befinden uns in einem Verdrängungsmarkt»: Der Zermatt-Chef Franz Julen hält die Amerikaner für überschätzt
# Newsletter «Quantensprung»: Die grossen Fragen aus Wissenschaft und Technologie auf dem Prüfstand – jeden Freitag in Ihrem Postfach
# Methode Bodycheck: wie Peter Spuhler die Juso und ihre Erbschaftssteuerinitiative ausspielt. Rettet er gerade die Schweiz?
# «Trumpsche Methoden»: Die Migros lässt die Preisverhandlungen mit den Markenherstellern eskalieren
# GASTKOMMENTAR - Der alte Westen: Chinas technologischer Fortschritt zeigt, dass Liberalismus kein Selbstläufer ist
# GASTKOMMENTAR - Wenn der Staat alles mit einem Preisschild versieht, droht Korruption
# DER ANDERE BLICK - Vom Musterschüler zum kranken Mann: Die Identitätskrise der deutschen Seele betrifft mehr als nur Politik und Wirtschaft
# Mitten in Hannover will der Islamverband Ditib eine Moschee errichten. Der grüne Oberbürgermeister setzt beim politischen Islam auf das Prinzip Hoffnung
# Orban umgarnt Trump im Weissen Haus mit russischer Propaganda
# Putin wirft dem Westen Kolonialismus vor – in Russland fürchtet er eine «Entkolonialisierung»
# Hast du schnell eine Minute? Wie Unterbrechungen unsere Arbeit sabotieren
# Ausverkauf bei der Unia: Die Gewerkschaft veräussert Aktien im Wert von über 80 Millionen Franken – und investiert in Beton
# Beim Anlegen mit börsenkotierten Anlagefonds gilt: Weniger ist mehr
# Wohneigentum kaufen mit Geldern aus der Pensionskasse – darum ist die Verpfändung zumeist besser als der Vorbezug
# Alle sprechen von einer KI-Blase – doch was passiert, wenn sie platzt?
# Die Pharma hat Basel reich gemacht. Und verschwenderisch. Droht nun das Ende des Schlaraffenlands?
# Fentanyl: Die Schweiz bereitet sich auf die Droge vor, die in den USA Hunderttausende tötet
# Der Zivilpolizist vom Zürcher Hauptbahnhof: Männer wie Stefan Scherrer sollen die Kontrolle über den öffentlichen Raum behalten
# Handy-Standortdaten, soziale Kontakte, Telefonlisten: Das Zürcher Steueramt sammelt intimste Daten von Steuerzahlern
# Zürich: Asbest in städtischer Wohnsiedlung Hardau II gefunden – Bewohner sollen ins Hotel
# Wie viel Barça passt zur Schweiz? Mit dem Nationaltrainer Rafel Navarro soll sich im Frauenfussball einiges ändern
# Unter Freunden ist kein Preis zu hoch
# Wahrscheinlichkeitsrechnung auf dem Spielfeld: Physiker und Ingenieure verschaffen dem Spitzenfussball neue Perspektiven
# Elternmord auf Spiesserdeutsch: Der Ludwigshafener «Tatort» ist blutgeil
# INTERVIEW - «Wir sind keine Psychiater, keine Polizisten oder Anwälte. Ich bin Betroffener, Moris ist Beteiligter»
# GASTKOMMENTAR - Was der Louvre-Raub mit Israel zu tun hat
# Glück gehabt: Diesen Echsen blüht Rettung vor dem Naturschutz
# Klimakonferenz in Brasilien: Wer finanziert die Anpassung an den Klimawandel?
# James Watson, Mitentdecker der DNA-Doppelhelix, ist im Alter von 97 Jahren gestorben

# %% [markdown]
# ## Generate a WordCloud

# %%
# Generate the word cloud
wordcloud = WordCloud(width=800, 
                      height=400, 
                      background_color='black').generate(wordcloud_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide the axes
plt.show()

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-11-09 18:58:23
# Python Version: 3.11.14
# -----------------------------------
